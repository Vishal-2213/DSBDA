# %%
import pandas as pd

# %%
df = pd.read_csv("DSBDALExam DataSets/HeartDisease/Cleavland.csv")

# %%
df
# Out:
#      63.0  1.0  1.0.1  145.0  233.0  1.0.2  2.0  150.0  0.0  2.3  3.0 0.0.1  \
# 0    67.0  1.0    4.0  160.0  286.0    0.0  2.0  108.0  1.0  1.5  2.0   3.0
# 1    67.0  1.0    4.0  120.0  229.0    0.0  2.0  129.0  1.0  2.6  2.0   2.0
# 2    37.0  1.0    3.0  130.0  250.0    0.0  0.0  187.0  0.0  3.5  3.0   0.0
# 3    41.0  0.0    2.0  130.0  204.0    0.0  2.0  172.0  0.0  1.4  1.0   0.0
# 4    56.0  1.0    2.0  120.0  236.0    0.0  0.0  178.0  0.0  0.8  1.0   0.0
# ..    ...  ...    ...    ...    ...    ...  ...    ...  ...  ...  ...   ...
# 297  45.0  1.0    1.0  110.0  264.0    0.0  0.0  132.0  0.0  1.2  2.0   0.0
# 298  68.0  1.0    4.0  144.0  193.0    1.0  0.0  141.0  0.0  3.4  2.0   2.0
# 299  57.0  1.0    4.0  130.0  131.0    0.0  0.0  115.0  1.0  1.2  2.0   1.0
# 300  57.0  0.0    2.0  130.0  236.0    0.0  2.0  174.0  0.0  0.0  2.0   1.0
# 301  38.0  1.0    3.0  138.0  175.0    0.0  0.0  173.0  0.0  0.0  1.0     ?
#
#      6.0  0
# 0    3.0  2
# 1    7.0  1
# 2    3.0  0
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns=['Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
       'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD']

# %%
df.describe()
# Out:
#               Age         Sex   ChestPain      RestBP        Chol         Fbs  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.410596    0.678808    3.165563  131.645695  246.738411    0.145695
# std      9.040163    0.467709    0.953612   17.612202   51.856829    0.353386
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     55.500000    1.000000    3.000000  130.000000  241.500000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope         AHD
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.986755  149.605960    0.327815    1.035430    1.596026    0.940397
# ...

# %%
for i in df.columns:
  print(i)
  print(df[i].value_counts())
  print("_________________________________")
# Out:
# Age
# 58.0    19
# 57.0    17
# 54.0    16
# 59.0    14
# 52.0    13
# 60.0    12
# 51.0    12
# 44.0    11
# 56.0    11
# 62.0    11
# 64.0    10
# 41.0    10
# 67.0     9
# 55.0     8
# 65.0     8
# 61.0     8
# 45.0     8
# 63.0     8
# 53.0     8
# 42.0     8
# 43.0     8
# 48.0     7
# 50.0     7
# 66.0     7
# 46.0     7
# 47.0     5
# 49.0     5
# 35.0     4
# 70.0     4
# 39.0     4
# 68.0     4
# 71.0     3
# 40.0     3
# 69.0     3
# 34.0     2
# 37.0     2
# 38.0     2
# 29.0     1
# 76.0     1
# 74.0     1
# 77.0     1
# Name: Age, dtype: int64
# _________________________________
# Sex
# 1.0    205
# 0.0     97
# Name: Sex, dtype: int64
# _________________________________
# ChestPain
# 4.0    144
# 3.0     86
# 2.0     50
# 1.0     22
# Name: ChestPain, dtype: int64
# _________________________________
# RestBP
# 120.0    37
# 130.0    36
# 140.0    32
# 110.0    19
# 150.0    17
# 138.0    12
# 128.0    12
# 125.0    11
# 160.0    11
# 112.0     9
# 132.0     8
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR',
#        'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
plt.hist
plt.show()

# %%
plt.hist(df['MaxHR'])
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.boxplot(data=df)
plt.show()

# %%
sns.pairplot(data=df)

# %%
df1 = df['Sex'].value_counts()

# %%
df1
# Out:
# 1.0    205
# 0.0     97
# Name: Sex, dtype: int64

# %%
data = [df1.iloc[0],df1.iloc[1]]
labels = ['Male', 'Female']

# %%
plt.pie(data, labels = labels, autopct='%.0f%%')
plt.show()

# %%
sns.set(style="whitegrid")

ax = sns.boxplot(x="Sex", y="Chol", data=df, showfliers = False)
ax = sns.scatterplot(x="Sex", y="Chol", data=df, color=".25")

plt.show()

# %%
plt.scatter(df['Age'], df['Chol'] , c ="blue")
 
# To show the plot
plt.show()
